# %%
import seaborn as sns

# %%
ds = [2, 14, 19, 21, 21, 21, 23, 24, 24, 25, 25, 25, 55, 254, 541]

# %%
sns.histplot(ds,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
df1=sns.load_dataset("iris")

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
sns.histplot(df1["sepal_width"],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
import pandas as pd
df3 = pd.read_csv("Data/iris.csv")

# %%
df3
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
import numpy as np
mu,sigma=3.0,1.0
p=np.random.lognormal(mu,sigma,1000)

# %%
p
# Out:
# array([7.54052002e+00, 1.54503633e+01, 1.08139760e+01, 1.23550222e+02,
#        3.30600354e+00, 1.42236752e+01, 9.41711853e+00, 9.98997152e+00,
#        8.72276987e+00, 4.56832662e+01, 4.30173342e+01, 3.82142937e+00,
#        2.21300567e+01, 5.04008827e+01, 6.89346312e+00, 1.58707008e+01,
#        2.02776850e+01, 1.15873720e+01, 8.91744301e+00, 1.11106158e+02,
#        6.44822956e+00, 2.31187925e+01, 8.28113893e+01, 8.11416886e+00,
#        1.16538431e+01, 3.63213175e+01, 3.55947599e+01, 6.99340834e+00,
#        2.21324147e+01, 1.65134845e+01, 4.24735507e+01, 5.70302323e+00,
#        3.01305998e+01, 9.11795300e+00, 9.44576241e+01, 1.94367347e+02,
#        3.33009211e+00, 1.59198228e+01, 6.66129956e+00, 2.74472284e+01,
#        5.98455423e+01, 5.72587769e+00, 4.38337661e+01, 3.54490256e+00,
#        1.68093646e+02, 7.07272383e+00, 9.44751605e+00, 7.94953854e+01,
#        3.89972918e+00, 6.64553491e+00, 3.61168607e+01, 9.75720481e+00,
# ...

# %%
plot_data(np.log(p))

# %%
# !pip install pandas_profiling
# Out:
# ...
#   Obtaining dependency information for pandas_profiling from https://files.pythonhosted.org/packages/57/b7/e13216265ae3135ecda13e966aad9ce04b7e7b3e2d87d056b032fc9f457c/pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for joblib~=1.1.0 from https://files.pythonhosted.org/packages/7c/91/d3ba0401e62d7e42816bc7d97b82d19c95c164b3e149a87c0a1c026a735e/joblib-1.1.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pydantic>=1.8.1 from https://files.pythonhosted.org/packages/16/ca/330c4f3bd983bb24ac12c7fd1e08c26c8aed70bc64498cf38c770321067f/pydantic-2.7.0-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/103.4 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/103.4 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 103.4/103.4 kB 1.2 MB/s eta 0:00:00
# ...

# %%
data3=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics_With_Python/main/Titanic.csv")

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas_profiling 
profile = data3.profile_report()
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 import pandas_profiling
#       2 profile = data3.profile_report()
#
# File c:\Python3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File c:\Python3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Values of lambda (average rate parameter)
lambdas = [1, 3, 5]

# Generate x values (number of events)
x = np.arange(0, 15)

plt.figure(figsize=(10, 6))

# Plot Poisson distribution for each lambda
for lambda_ in lambdas:
    # Calculate the PMF for each value of x
    pmf = poisson.pmf(x, lambda_)
    # Plot the PMF
    plt.plot(x, pmf, label=f'$\lambda$={lambda_}')

plt.title('Poisson Distribution')
plt.xlabel('Number of Events (k)')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()
