# %%
import pandas as pd

# %%
data=pd.read_csv("sample.csv")

# %%
# pandas will work with structured data.
data
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()  # head method gives top 5 record.
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
data.head(10) # we can specify the number
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
# 5  2011                    A  Agriculture, Forestry and Fishing          a_0
# 6  2011                    A  Agriculture, Forestry and Fishing          a_0
# 7  2011                    A  Agriculture, Forestry and Fishing          a_0
# 8  2011                    A  Agriculture, Forestry and Fishing          a_0
# 9  2011                    A  Agriculture, Forestry and Fishing        b_1-5
#
#                                           variable  value               unit
# ...

# %%
data.tail() # by default last  record.
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 17023  2021                  all       All Industries  j_Grand_Total
# 17024  2021                  all       All Industries  j_Grand_Total
# 17025  2021                  all       All Industries  j_Grand_Total
# 17026  2021                  all       All Industries  j_Grand_Total
# 17027  2021                  all       All Industries  j_Grand_Total
#
#                           variable    value               unit
# 17023                 Total income   757504  DOLLARS(millions)
# 17024            Total expenditure   654404  DOLLARS(millions)
# 17025  Operating profit before tax    85116  DOLLARS(millions)
# 17026                 Total assets  2512677  DOLLARS(millions)
# 17027        Fixed tangible assets   591351  DOLLARS(millions)

# %%
data.tail(2) # last two record
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 17026  2021                  all       All Industries  j_Grand_Total
# 17027  2021                  all       All Industries  j_Grand_Total
#
#                     variable    value               unit
# 17026           Total assets  2512677  DOLLARS(millions)
# 17027  Fixed tangible assets   591351  DOLLARS(millions)

# %%
data.columns # all columns details will be shown
# Out:
# Index(['year', 'industry_code_ANZSIC', 'industry_name_ANZSIC', 'rme_size_grp',
#        'variable', 'value', 'unit'],
#       dtype='object')

# %%
list(data.columns) # converting all the columns in to list
# Out:
# ['year',
#  'industry_code_ANZSIC',
#  'industry_name_ANZSIC',
#  'rme_size_grp',
#  'variable',
#  'value',
#  'unit']

# %%
data.head(3)
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                   variable  value               unit
# 0            Activity unit  46134              COUNT
# 1   Rolling mean employees      0              COUNT
# 2  Salaries and wages paid    279  DOLLARS(millions)

# %%
# ok now we want some specific column

# %%
data[["value","year","rme_size_grp"]].head(2)
# Out:
#    value  year rme_size_grp
# 0  46134  2011          a_0
# 1      0  2011          a_0

# %%
# we have to provide the list of column to ascess limited column
# this is about column selection.
data[["value","year","rme_size_grp"]].head(2)
# Out:
#    value  year rme_size_grp
# 0  46134  2011          a_0
# 1      0  2011          a_0

# %%
data["rme_size_grp"].head(2) # its type would be series
# Out:
# 0    a_0
# 1    a_0
# Name: rme_size_grp, dtype: object

# %%
# series and list are almost same but there are some of the differences in between them.
# series having indexes with it.

# %%
# Read excel data from pandas
data1=pd.read_excel("LoginCredentials.xlsx")

# %%
data1.head(5)
# Out:
#    SrNo Client        Account Name      User Name      Password          URL  \
# 0   1.0    UPS  Danaher IDT-Canada  BridgeNet_IDT  Bridgenet750  www.ups.com
# 1   2.0    UPS      Danaher IDT-US  BridgeNet_IDT  Bridgenet750  www.ups.com
# 2   3.0    UPS           ALLEGHENY    AlleghenyPA    Billing123  www.ups.com
# 3   4.0    UPS     Prada 2- Canada       jp.prada  Shipping1234  www.ups.com
# 4   5.0    UPS     Prada 2- Canada       jp.prada  Shipping1234  www.ups.com
#
#        Type of Invoice        Country or Region  \
# 0          My Invoices         Canada - English
# 1          My Invoices  United States - English
# 2     My Plan Invoices  United States - English
# 3  My Account Invoices         Canada - English
# 4     My Plan Invoices         Canada - English
#
#                              Destination Folder Path Active/Inactive  \
# 0         C:\UPS Updated Template\Danaher IDT\Canada          Active
# 1             C:\UPS Updated Template\Danaher IDT\US          Active
# ...

# %%
data1.tail(2)
# Out:
#     SrNo Client Account Name User Name Password  URL Type of Invoice  \
# 42   NaN    NaN          NaN       NaN      NaN  NaN             UPS
# 43   NaN    NaN          NaN       NaN      NaN  NaN             UPS
#
#                         Country or Region Destination Folder Path  \
# 42     Dover-Netherlands-My Plan Invoices               Dover_BNS
# 43  Dover-Netherlands-My Account Invoices               Dover_BNS
#
#      Active/Inactive    Completed        Invoice Count  Unnamed: 12
# 42  %Ycil7LG&Qw5d79^  www.ups.com      My Plan Invoice  Netherlands
# 43  %Ycil7LG&Qw5d79^  www.ups.com  My Account Invoices  Netherlands

# %%
data2=pd.read_excel("airline.xlsx",sheet_name="Sheet2")

# %%
data2
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574
# 5  1953  2.731  0.322  0.3593  1.926  0.711
# 6  1954  3.025  0.335  0.4025  1.964  0.776
# 7  1955  3.562  0.350  0.3961  2.116  0.827
# 8  1956  3.979  0.361  0.3822  2.435  0.800

# %%
# it treates 1st rows as header
pd.read_excel("airline.xlsx",sheet_name="Sheet3",header=None)
# Out:
#        0       1      2       3      4      5
# 0   1960   5.554  0.441  0.3193  3.089  1.481
# 1   1961   5.465  0.460  0.3079  3.122  1.736
# 2   1962   5.825  0.485  0.3783  3.184  1.926
# 3   1963   6.876  0.506  0.4180  3.263  2.041
# 4   1964   7.823  0.538  0.5163  3.412  1.997
# 5   1965   9.120  0.564  0.5879  3.623  2.257
# 6   1966  10.512  0.586  0.5369  4.074  2.742
# 7   1967  13.020  0.622  0.4443  4.710  3.564
# 8   1968  15.261  0.666  0.3052  5.217  4.767
# 9   1969  16.313  0.731  0.2332  5.569  6.511
# 10  1970  16.002  0.831  0.1883  5.495  7.627
# 11  1971  15.876  0.906  0.2023  5.334  8.673
# 12  1972  16.662  1.000  0.2506  5.345  8.331
# 13  1973  17.014  1.056  0.2668  5.662  8.557
# 14  1974  19.305  1.131  0.2664  5.729  9.508
# 15  1975  18.721  1.247  0.2301  5.722  9.062

# %%
# setting own column name
# names paramere
data4=pd.read_excel("airline.xlsx",sheet_name="Sheet3",header=None,names=['a','b','c','d','e','f'])

# %%
# writing data to file.

data4.to_csv("Test1.csv",index=False,header=None)

# %%
data4.to_excel("demo1.xlsx")

# %%
# reading data from gihub_csv-------------

# able to load data from git hub----------


pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# read from html

dataHtml=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(dataHtml)
# Out:
# list

# %%
len(dataHtml)
# Out:
# 1

# %%
dataHtml[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
dataHtml[0].to_csv("playserdata.csv",index=False)
