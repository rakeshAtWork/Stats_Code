# %%
import seaborn as sns

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
import statistics

# %%
df = pd.read_csv("tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill']) # calculation of mean
# Out:
# 19.78594262295082

# %%
np.median(df['total_bill']) # calculation of median
# Out:
# 17.795

# %%
statistics.mode(df['total_bill'])
# Out:
# 13.42

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.histplot(df['total_bill'],kde=True) # does this look likie normally distributed? I think no.
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df1=pd.read_csv("iris.csv")

# %%
df1.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.boxplot(df1['sepal.length'])
# Out:
# <Axes: ylabel='sepal.length'>

# %%
sns.histplot(df1['sepal.length']) # This is not gaussian distribution
# Out:
# <Axes: xlabel='sepal.length', ylabel='Count'>

# %%
sns.histplot(df1['sepal.width'],kde=True) # This ia s normally distributed Grapth.
# Out:
# <Axes: xlabel='sepal.width', ylabel='Count'>
